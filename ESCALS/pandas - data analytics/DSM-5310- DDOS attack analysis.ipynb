# %%
################################################################
# The script will replay all the attempts identified
#   failed-2.csv - the missing attempts
#   success-2.csv  - the successfulling submitted attemptsf from splunk
#     * splunk query - index=devmath_prod_cas_core | search message="*Successfully submitted attempt*" | uniq message | table message
#   output.csv - replayed attempts with results <404,xxx> or <200,xxx> 
################################################################

import json
import pandas as pd
import requests

def sendToAnalytics(attempt):
    url = "https://cas-devmath.cengage.info/services/casadmin/v2/attempts/{0}/actions/analytics-replay/invoke".format(attempt)
    # print('calling the url : {0}'.format(url))
    # authorization - will be casadmin, <whatever in app builder>
    headers = {
        'accept': "application/json",
        'authorization': "Basic Y2FzYWRtaW46czQ4YWQxbQ==",
        'cache-control': "no-cache",
        'postman-token': "f2a9e2a6-0d5a-995c-2e23-bfc2291083b3"
        }
#     response = requests.request("POST", url, headers=headers)
    outputMessage = "{0},{1}".format(response.status_code, attempt)
    print(outputMessage)
    return outputMessage
    

dff = pd.read_csv('/Users/mtony/Downloads/failed-2.csv')
dfs = pd.read_csv('/Users/mtony/Downloads/success-2.csv')
# print(dff.describe())
# print(dfs.describe())
dff = dff.drop_duplicates()
dfs = dfs.drop_duplicates()
dfs = dfs.replace({'Successfully submitted attempt ': '','to analytics.': ''}, regex=True)
dfs = dfs.applymap(lambda x: x.strip() if type(x) is str else x)
difference = dff[~dff.takeid.isin(dfs.message)]
# print (difference.describe())
# test = difference.head()
df = pd.DataFrame(difference.takeid.apply(sendToAnalytics))
df.to_csv('/Users/mtony/Downloads/output.csv')
# Out:
# 200,80fbd2bb-015e-1000-0000-12595b6b821d
# 200,80ea6737-015e-1000-0003-12595b6b821d
# 200,8101402b-015e-1000-0000-83a741eb2c16
# 200,80e52b19-015e-1000-0003-019bb2dce653
# 200,8097277a-015e-1000-0003-b921c3e48931
# 200,80d7252e-015e-1000-0003-b921c3e48931
# 200,80c79e9c-015e-1000-0002-b921c3e48931
# 200,0bcc5f7c-015e-1000-0003-fb1b7b1d4489
# 200,808bd471-015e-1000-0003-019bb2dce653
# 200,7ba1decc-015e-1000-0002-12595b6b821d
# 200,8055b433-015e-1000-0002-83a741eb2c16
# 200,7f3ce504-015e-1000-0003-019bb2dce653
# 200,6a6f0ddf-015e-1000-0003-12595b6b821d
# 200,7f522fda-015e-1000-0003-12595b6b821d
# 200,7f4c07d8-015e-1000-0003-b921c3e48931
# 200,7f3d508d-015e-1000-0003-83a741eb2c16
# 200,7ee2ac0e-015e-1000-0002-83a741eb2c16
# 200,7eff567c-015e-1000-0002-12595b6b821d
# 200,74c67733-015e-1000-0003-b921c3e48931
# 200,7ef7aead-015e-1000-0002-12595b6b821d
# 200,6f8de546-015e-1000-0003-83a741eb2c16
# 200,14a13956-015e-1000-0003-019bb2dce653
# 200,7ee2fc80-015e-1000-0002-12595b6b821d
# ...

# %%
import json
import pandas as pd
import requests


dff = pd.read_csv('/Users/mtony/Downloads/output.csv')
dfs = pd.read_csv('/Users/mtony/Downloads/Ran-script-1.csv')
# print(dff.describe())
# print(dfs.describe())
dff = dff.drop_duplicates()
dfs = dfs.drop_duplicates()
dff = dff.replace({'200,': ''}, regex=True)
dff = pd.DataFrame(dff.takeid)
dff.describe()

dfs = dfs.replace({'Successfully submitted attempt ': '','to analytics.': ''}, regex=True)
dfs = dfs.applymap(lambda x: x.strip() if type(x) is str else x)
difference = dff[~dff.takeid.isin(dfs.message)]

difference
# Out:
# Empty DataFrame
# Columns: [takeid]
# Index: []
